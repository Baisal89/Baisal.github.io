# %% [markdown]
# <a href="https://colab.research.google.com/github/Baisal89/Baisal89.github.io/blob/master/DoingExtraWork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !curl https://archive.ics.uci.edu/ml/machine-learning-databases/00303/perfume_data.xlsx.
# Out:
# <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>404 Not Found</title>
# </head><body>
# <h1>Not Found</h1>
# <p>The requested URL /ml/machine-learning-databases/00303/perfume_data.xlsx. was not found on this server.</p>
# <hr>
# <address>Apache/2.4.6 (CentOS) OpenSSL/1.0.2k-fips SVN/1.7.14 Phusion_Passenger/4.0.53 mod_perl/2.0.10 Perl/v5.16.3 Server at archive.ics.uci.edu Port 443</address>
# </body></html>

# %%
perfume_data = pd.read_excel('https://archive.ics.uci.edu/ml/machine-learning-databases/00303/perfume_data.xlsx')

# %%
print(perfume_data.shape)
perfume_data.head(4)
# Out:
# (19, 29)
#       ajayeb  64558  64556  64543  ...  64528.2  64528.3  64528.4  64528.5
# 0      ajmal  60502  60489  61485  ...    61485    60487    60472    60472
# 1     amreaj  57040  57040  57040  ...    58041    58041    58041    58041
# 2       aood  71083  72087  71091  ...    71103    72103    72103    72098
# 3  asgar_ali  68209  68209  68216  ...    68223    68223    68223    68230
#
# [4 rows x 29 columns]

# %%
perfume_data.columns
# Out:
# Index([  'ajayeb',      64558,      64556,      64543,  '64543.1',      64541,
#         '64543.2',  '64543.3',  '64541.1',  '64541.2',  '64541.3',  '64541.4',
#         '64541.5',  '64541.6',      64528,  '64528.1',      63529,  '63529.1',
#         '64541.7',  '64541.8',  '64541.9', '64541.10', '64541.11', '64541.12',
#        '64541.13',  '64528.2',  '64528.3',  '64528.4',  '64528.5'],
#       dtype='object')

# %%
column_headers = (['measurment1','measurment2','measurment3','measurment4','measurment5','measurment6','measurment7','measurment8','measurment9','measurment10','measurment11','measurment12','measurment13','measurment14','measurment15','measurment16','measurment17','measurment18'])

# %%
perfume_data = pd.read_excel('https://archive.ics.uci.edu/ml/machine-learning-databases/00303/perfume_data.xlsx',header=None, skiprows=1, names = column_headers)
perfume_data.head(50)
# Out:
#                                                                               measurment1  ...  measurment18
# ajmal            60502 60489 61485 60487 61485 61513 60515 60500 60500 60487        60500  ...         60472
# amreaj           57040 57040 57040 58041 58041 58041 58041 57042 57042 58043        58043  ...         58041
# aood             71083 72087 71091 71095 71099 72103 71099 72099 72099 73098        72094  ...         72098
# asgar_ali        68209 68209 68216 68216 68223 68223 68223 68223 68230 68230        68230  ...         68230
# bukhoor          71046 71046 71046 71046 71046 71046 71046 71046 71046 70046        69046  ...         71048
# burberrry        61096 61096 60093 60092 60093 60093 61096 61096 61096 61096        60092  ...         60089
# dehenalaod       68132 69137 69137 68137 68137 69142 69142 68137 68137 68137        69142  ...         69136
# junaid           71590 71575 71574 71560 71560 71559 72573 71559 71559 71559        71559  ...         72556
# ...

# %%
perfume_data.describe()
# Out:
#         measurment1   measurment2  ...  measurment17  measurment18
# count     19.000000     19.000000  ...     19.000000     19.000000
# mean   67946.473684  68212.473684  ...  68094.684211  68094.842105
# std     9015.117435   9067.071568  ...   8964.069779   9050.241748
# min    46015.000000  46015.000000  ...  46015.000000  46015.000000
# 25%    63030.500000  63030.500000  ...  63025.500000  62525.500000
# 50%    68230.000000  68230.000000  ...  68223.000000  68230.000000
# 75%    72046.500000  72841.000000  ...  72329.500000  72327.000000
# max    85056.000000  85056.000000  ...  85056.000000  85056.000000
#
# [8 rows x 18 columns]

# %%
perfume_data.isnull().sum()
# Out:
# measurment1     0
# measurment2     0
# measurment3     0
# measurment4     0
# measurment5     0
# measurment6     0
# measurment7     0
# measurment8     0
# measurment9     0
# measurment10    0
# measurment11    0
# measurment12    0
# measurment13    0
# measurment14    0
# measurment15    0
# measurment16    0
# measurment17    0
# measurment18    0
# dtype: int64

# %%
perfume_data.plot.scatter('measurment4', 'measurment17') #scatter plot

# %%
perfume_data.measurment4.hist(bins=30)#histogram

# %%
perfume_data.measurment5.plot.density()

# %%
import seaborn as sns
sns.set(style = 'whitegrid', color_codes=True)
graph = sns.pairplot(perfume_data)

# %%
perfume_data = sns.load_dataset('perfume_data')
perfume_data = perfume_data.pivot('perfume_handhel_odor', 'names_of_perfumes')
dysplay_data = sns.heatmap(perfume_data)

# %%
'ajmal', 'amreaj', 'aood', 'asgar_ali', 'bukhoor', 'burberrry', 'dehenalaod', 'junaid', 'kausar', 'rose', 'solidmusk', 'TeaTreeOil', 'raspberry', 'RoseMusk', 'strawberry', 'constrected2', 'carolina_herrera', 'oudh_ma`alattar', 'constrcted'
